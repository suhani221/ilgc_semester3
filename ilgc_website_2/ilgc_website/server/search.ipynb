# %%
import pandas as pd
import numpy as np
import math
import pandas as pd
import folium
import branca

# %%
df= pd.read_csv('/Users/suhaniagarwal/Desktop/ilgc_website_2/gfg/INDIA_LAT_LONG.csv')
df
# Out:
#              key               place_name admin_name1  latitude  longitude  \
# 0      IN/110001          Connaught Place   New Delhi   28.6333    77.2167
# 1      IN/110002               Darya Ganj   New Delhi   28.6333    77.2500
# 2      IN/110003                  Aliganj   New Delhi   28.6500    77.2167
# 3      IN/110004       Rashtrapati Bhawan   New Delhi   28.6500    77.2167
# 4      IN/110005  Lower Camp Anand Parbat   New Delhi   28.6500    77.2000
# ...          ...                      ...         ...       ...        ...
# 11037  IN/855116               Thakurganj       Bihar   24.9833    81.0583
# 11038  IN/855117                Taiyabpur       Bihar   24.9833    81.0583
# 11039  IN/855119               Terhagachi       Bihar   24.9833    81.0583
# 11040  IN/855121               Balarampur       Bihar   24.9833    81.0583
# 11041  IN/855126                   Tulsia       Bihar   24.9833    81.0583
#
#        accuracy
# 0           4.0
# 1           4.0
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 11037       NaN
# 11038       NaN
# 11039       NaN
# 11040       NaN
# 11041       NaN
#
# [11042 rows x 6 columns]

# %%
df["pincode"]=df["key"].str.split("/").str.get(1)

# %%
# def search(latitude,longitude):
#     for index, row in df.iterrows():
#         if row['latitude'] == latitude and row['longitude'] == longitude:
#             print('Found the value 3 in column1 and the value 9 in column2 at index', index)
        
# latitude=28.6500
# longitude=77.2167
# search(latitude,longitude)

# %%
def search(pincode):
    pincode=str(pincode)
    for index, row in df.iterrows():
        if row['pincode'] == pincode:
            lati1=row["latitude"]
            loni2=row["longitude"]
            return(lati1,loni2)
            break
    else:
        print("not found")

pincode=143001
lati1,loni1=search(pincode)
print(lati1,loni1)
# Out:
# 31.6331 74.8656

# %%
data= pd.read_csv('/Users/suhaniagarwal/Desktop/ilgc_website_2/Map Maker/Punjab_HWC_Data/combined.csv')
data
# Out:
#           Block Name Category District Name  HealthBlock ID  \
# 0                NaN     UPHC           NaN             NaN
# 1                NaN     UPHC           NaN             0.0
# 2        Baba Bakala      SHC           NaN         40729.0
# 3        Baba Bakala      SHC           NaN         40729.0
# 4        Baba Bakala      SHC           NaN         40729.0
# ...              ...      ...           ...             ...
# 1443  Sur Singh Wala      SHC           NaN         40418.0
# 1444  Sur Singh Wala      SHC           NaN         40418.0
# 1445  Sur Singh Wala      SHC           NaN         40418.0
# 1446  Sur Singh Wala      SHC           NaN         40418.0
# 1447  Sur Singh Wala      SHC           NaN         40418.0
#
#                                                 HFI Highlight  \
# 0                                    UPHC Putligarh       NaN
# 1     Bhai Dharam Singh Memorial Sattelite Hospital       NaN
# 2                                          Balsaran       NaN
# 3                                          Bedadpur       NaN
# 4                                      Buley Nangal       NaN
# ...                                             ...       ...
# 1443                                       Dialpura       NaN
# 1444                                         Khalra       NaN
# 1445                                      Mari Theh       NaN
# 1446                                       Pahuwind       NaN
# 1447                                          Sugga       NaN
#
#                                              Hyper Link   Latitude  Longitude  \
# 0     https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.606140  74.939998
# 1     https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.661178  74.866946
# 2     https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.629271  74.881373
# 3     https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.570835  75.277618
# 4     https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.512810  75.256474
# ...                                                 ...        ...        ...
# 1443  https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.312877  74.749983
# 1444  https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.400534  74.615930
# 1445  https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.313812  74.659988
# 1446  https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.350313  74.679015
# 1447  https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.661033  74.891616
#
#          Nin 2 Hfi  ...                                          HFI.1  \
# 0     8.132252e+09  ...                                 UPHC Putligarh
# 1     4.437325e+09  ...  Bhai Dharam Singh Memorial Sattelite Hospital
# 2     6.138843e+09  ...                                       Balsaran
# 3     8.885463e+09  ...                                       Bedadpur
# 4     1.335326e+09  ...                                   Buley Nangal
# ...            ...  ...                                            ...
# 1443  6.668373e+09  ...                                       Dialpura
# 1444  8.425477e+09  ...                                         Khalra
# 1445  2.618649e+09  ...                                      Mari Theh
# 1446  4.231858e+09  ...                                       Pahuwind
# 1447  4.272486e+09  ...                                          Sugga
#
#      Geometry (generated) Latitude (generated) Longitude (generated)  test  \
# 0                     NaN            31.606140             74.939998   NaN
# 1                     NaN            31.661178             74.866946   NaN
# 2                     NaN            31.629271             74.881373   NaN
# 3                     NaN            31.570835             75.277618   NaN
# 4                     NaN            31.512810             75.256474   NaN
# ...                   ...                  ...                   ...   ...
# 1443                  NaN            31.312877             74.749983   NaN
# 1444                  NaN            31.400534             74.615930   NaN
# 1445                  NaN            31.313812             74.659988   NaN
# 1446                  NaN            31.350313             74.679015   NaN
# 1447                  NaN            31.661033             74.891616   NaN
#
#      breastcancer diabetes footfall  Hypertension   Oralcancer
# 0             NaN      NaN      215           NaN           NaN
# 1             NaN      NaN   34,708           NaN           NaN
# 2           1,737      375    7,283         2,946         1,232
# 3             651      448    7,866           978           964
# 4           1,429    2,286    7,745         3,290         3,242
# ...           ...      ...      ...           ...           ...
# 1443           20      907    5,148         1,451            79
# 1444          193      971    3,953         1,012           745
# 1445          265      461    1,502           849           893
# 1446           50      671    4,154           759           379
# 1447            0      606    1,838           599           373
#
# [1448 rows x 26 columns]

# %%
R = 6378.1 
brng = 1.57 
d = 50
lat1 = math.radians(lati1) 
lon1 = math.radians(loni1) 
lat2 = math.asin( math.sin(lat1)*math.cos(d/R) + math.cos(lat1)*math.sin(d/R)*math.cos(brng))
lon2 = lon1 + math.atan2(math.sin(brng)*math.sin(d/R)*math.cos(lat1),math.cos(d/R)-math.sin(lat1)*math.sin(lat2))
lat2 = math.degrees(lat2)
lon2 = math.degrees(lon2)
print(lat2)
print(lon2)
# Out:
# 30.73651079379689
# 77.30976864102443

# %%
lati1=31.606140
loni1=74.866946
lat2=31.661178
lon2=74.939998


data_query = data[(data['Latitude'] >= lati1) & (data['Latitude'] <= lat2) 
                  & (data['Longitude'] >= loni1) & (data['Longitude'] <= lon2)]
data_query
# Out:
#           Block Name Category District Name  HealthBlock ID  \
# 2        Baba Bakala      SHC           NaN         40729.0
# 9        Baba Bakala      SHC           NaN         40729.0
# 77          TARSIKKA      SHC           NaN           223.0
# 104            VERKA      SHC           NaN           225.0
# 110            VERKA      SHC           NaN           225.0
# 1419      Khem Karan      SHC           NaN         40415.0
# 1447  Sur Singh Wala      SHC           NaN         40418.0
#
#                       HFI Highlight  \
# 2                Balsaran       NaN
# 9     Ghuhatwind  Hinduan       NaN
# 77                 Tangra       NaN
# 104               Gumtala       NaN
# 110       Wadala Bhitewid       NaN
# 1419             Bhangala       NaN
# 1447                Sugga       NaN
#
#                                              Hyper Link   Latitude  Longitude  \
# 2     https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.629271  74.881373
# 9     https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.629271  74.881372
# 77    https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.619343  74.888623
# 104   https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.619705  74.907758
# 110   https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.615886  74.923235
# 1419  https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.659900  74.891400
# 1447  https://ab-hwc.nhp.gov.in/Gallery/tableuphotoG...  31.661033  74.891616
#
#          Nin 2 Hfi  ...                HFI.1 Geometry (generated)  \
# 2     6.138843e+09  ...             Balsaran                  NaN
# 9     4.383752e+09  ...  Ghuhatwind  Hinduan                  NaN
# 77    7.742178e+09  ...               Tangra                  NaN
# 104   6.482475e+09  ...              Gumtala                  NaN
# 110   3.264545e+09  ...      Wadala Bhitewid                  NaN
# 1419  7.634557e+09  ...             Bhangala                  NaN
# 1447  4.272486e+09  ...                Sugga                  NaN
#
#      Latitude (generated) Longitude (generated)  test breastcancer diabetes  \
# 2               31.629271             74.881373   NaN        1,737      375
# 9               31.629271             74.881372   NaN          263      279
# 77              31.619343             74.888623   NaN           82    1,166
# 104             31.619705             74.907758   NaN          580    3,174
# 110             31.615886             74.923235   NaN          465    1,486
# 1419            31.659900             74.891400   NaN           24      756
# 1447            31.661033             74.891616   NaN            0      606
#
#      footfall  Hypertension   Oralcancer
# 2       7,283         2,946         1,232
# 9       7,219         1,032         1,037
# 77     10,311         2,313           383
# 104    12,686         3,218         2,843
# 110     5,271         1,590        1,186﻿
# 1419    2,820           756           756
# 1447    1,838           599           373
#
# [7 rows x 26 columns]

# %%
def popup_html(row):
    i = row
    breastcancer=data_query['breastcancer'].iloc[i] 
    diabetes=data_query['diabetes'].iloc[i]
    footfall = data_query['footfall'].iloc[i] 
    hypertensioon=data_query['Hypertension'].iloc[i] 
    Oralcancer = data_query[' Oralcancer '].iloc[i]
    Latitude = data_query['Latitude'].iloc[i]
    Longitude = data_query['Longitude'].iloc[i]
    Block_Name = data_query['HFI'].iloc[i]

    left_col_color = "#f2f0d3"
    right_col_color = "#f2f0d3"
    black="#000000"
    
    
    html = """<!DOCTYPE html>
<html>

<head>
<h4 style="margin-bottom:10"; width="200px">{}</h4>""".format(Block_Name) + """

</head>
    <table style="height: 126px; width: 350px;">
<tbody>

<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #000000;">Latitude</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Latitude) + """
</tr>

<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: black;">Longitude</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Longitude) + """
</tr>


<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #000000;">Footfall</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(footfall) + """
</tr>

<tr>
<td style="background-color: """+ left_col_color +""";">
<span style="color: black;">breastcancer</span>
</td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(breastcancer) + """
</tr>


<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #000000;">Diabetes</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(diabetes) + """
</tr>

<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #000000;">Hypertensioon</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(hypertensioon) + """
</tr>

<tr>
<td style="background-color: """+ left_col_color +""";"><span style="color: #000000;">Oralcancer</span></td>
<td style="width: 150px;background-color: """+ right_col_color +""";">{}</td>""".format(Oralcancer) + """
</tr>

</tbody>
</table>
</html>
"""
    return html

# %%
map = folium.Map(location=[lati1, loni1], zoom_start=12)
folium.Circle(location=[lati1, loni1], radius=15000, weight=1, color="#000").add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be1035a5d0c7cb97b18feb2def3a8c09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be1035a5d0c7cb97b18feb2def3a8c09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be1035a5d0c7cb97b18feb2def3a8c09 = L.map(
#                 &quot;map_be1035a5d0c7cb97b18feb2def3a8c09&quot;,
#                 {
#                     center: [31.60614, 74.866946],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40e522d3cdd9df5cce8433e4c65c6a7e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_be1035a5d0c7cb97b18feb2def3a8c09);
#
#
#             var circle_97e33b148a3a547c3c117eb29d9a687f = L.circle(
#                 [31.60614, 74.866946],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15000, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_be1035a5d0c7cb97b18feb2def3a8c09);
#
#
#             var marker_fb49cb0a4f122dc521d1d1d4be64412f = L.marker(
#                 [31.6292707, 74.8813728],
#                 {}
#             ).addTo(map_be1035a5d0c7cb97b18feb2def3a8c09);
#
#
#             var icon_5ddeb5eea9cfeb38cff66e67cb459e56 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plus&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fb49cb0a4f122dc521d1d1d4be64412f.setIcon(icon_5ddeb5eea9cfeb38cff66e67cb459e56);
#
#
#         var popup_20ad535175d007c8294ef471b7d7df76 = L.popup({&quot;maxWidth&quot;: 500});
#
#
#
#                 var html_76c252e64171d7c06498a76cbccab120 = $(`&lt;div id=&quot;html_76c252e64171d7c06498a76cbccab120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;!DOCTYPE html&gt; &lt;html&gt;  &lt;head&gt; &lt;h4 style=&quot;margin-bottom:10&quot;; width=&quot;200px&quot;&gt;Balsaran&lt;/h4&gt;  &lt;/head&gt;     &lt;table style=&quot;height: 126px; width: 350px;&quot;&gt; &lt;tbody&gt;  &lt;tr&gt; &lt;td style=&quot;background-color: #f2f0d3;&quot;&gt;&lt;span style=&quot;color: #000000;&quot;&gt;Latitude&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;31.6292707&lt;/td&gt; &lt;/tr&gt;  &lt;tr&gt; &lt;td style=&quot;background-color: #f2f0d3;&quot;&gt;&lt;span style=&quot;color: black;&quot;&gt;Longitude&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;74.8813728&lt;/td&gt; &lt;/tr&gt;   &lt;tr&gt; &lt;td style=&quot;background-color: #f2f0d3;&quot;&gt;&lt;span style=&quot;color: #000000;&quot;&gt;Footfall&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;7,283&lt;/td&gt; &lt;/tr&gt;  &lt;tr&gt; &lt;td style=&quot;background-color: #f2f0d3;&quot;&gt; &lt;span style=&quot;color: black;&quot;&gt;breastcancer&lt;/span&gt; &lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;1,737&lt;/td&gt; &lt;/tr&gt;   &lt;tr&gt; &lt;td style=&quot;background-color: #f2f0d3;&quot;&gt;&lt;span style=&quot;color: #000000;&quot;&gt;Diabetes&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;375&lt;/td&gt; &lt;/tr&gt;  &lt;tr&gt; &lt;td style=&quot;background-color: #f2f0d3;&quot;&gt;&lt;span style=&quot;color: #000000;&quot;&gt;Hypertensioon&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;2,946&lt;/td&gt; &lt;/tr&gt;  &lt;tr&gt; &lt;td style=&quot;background-color: #f2f0d3;&quot;&gt;&lt;span style=&quot;color: #000000;&quot;&gt;Oralcancer&lt;/span&gt;&lt;/td&gt; &lt;td style=&quot;width: 150px;background-color: #f2f0d3;&quot;&gt;1,232&lt;/td&gt; &lt;/tr&gt;  &lt;/tbody&gt; &lt;/table&gt; &lt;/html&gt; &lt;/div&gt;`)[0];
#                 popup_20ad535175d007c8294ef471b7d7df76.setContent(html_76c252e64171d7c06498a76cbccab120);
#
#
#
#         marker_fb49cb0a4f122dc521d1d1d4be64412f.bindPopup(popup_20ad535175d007c8294ef471b7d7df76)
#         ;
#
#
#
#
#             var feature_group_a33eca6ab930d151afe7ecf1c6602a26 = L.featureGroup(
#                 {}
#             ).addTo(map_be1035a5d0c7cb97b18feb2def3a8c09);
#
#
#             var circle_5b1d779c5b559d313cb6d7872786213c = L.circle(
#                 [31.6292707, 74.8813728],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&q

# %%
incidents = folium.map.FeatureGroup()
control_scale=True
zoom_start=14
for lat, lng, cat in zip(data_query.Latitude, data_query.Longitude, data_query.Category):
    if (cat == 'UPHC'):
            incidents.add_child(
            folium.Circle(
            [lat, lng],
            radius=float(2000), 
            color="red",
            opacity=0.0,
            fill=True,
            fill_color='red',
            fill_opacity=0.0 ))
    if (cat == 'PHC'):
            incidents.add_child(
            folium.Circle(
            [lat, lng],
            radius=float(2000), 
            color="blue",
            opacity=0.1,
            fill=True,
            fill_color='blue',
            fill_opacity=0.1 ))
    if (cat == 'SHC'):
            incidents.add_child(
            folium.Circle(
            [lat, lng],
            radius=float(2000), 
            color="green",
            fill=True,
            opacity=0.0,
            fill_color='green',
            fill_opacity=0.1 ))

    for i in range(0,len(data_query)):
        html = popup_html(i)
        iframe = branca.element.IFrame(html=html,width=510,height=280)
        popup = folium.Popup(folium.Html(html, script=True), max_width=500)
        if (data_query['Category'].iloc[i] == 'UPHC'):
            folium.Marker([data_query['Latitude'].iloc[i],data_query['Longitude'].iloc[i]],
            popup=popup,icon=folium.Icon(color="red", icon="plus", prefix='fa')).add_to(map)
        if (data_query['Category'].iloc[i] == 'SHC'):
            folium.Marker([data_query['Latitude'].iloc[i],data_query['Longitude'].iloc[i]],
            popup=popup,icon=folium.Icon(color="green", icon="plus", prefix='fa')).add_to(map)
        if (data_query['Category'].iloc[i] == 'PHC'):
            folium.Marker([data_query['Latitude'].iloc[i],data_query['Longitude'].iloc[i]],
            popup=popup,icon=folium.Icon(color="blue", icon="plus", prefix='fa')).add_to(map)  
    
        map.add_child(incidents)

# %%
map.save("suhani.html")
